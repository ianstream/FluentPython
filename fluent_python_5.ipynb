# %%
# fluent python chap 5

"""
파이썬 함수는 일급 객체이다. 다음과 특징을 가진다.

실행 시 생성할수 있다
데이터 구조체의 변수나 요소에 할당가능
함수 인자로 전달 가능
함수 결과로 반환 가능
"""
# Out:
# '\n파이썬 함수는 일급 객체이다. 다음과 특징을 가진다.\n\n실행 시 생성할수 있다\n데이터 구조체의 변수나 요소에 할당가능\n함수 인자로 전달 가능\n함수 결과로 반환 가능\n'

# %%
# 5-1

# %%
def factorial(n):
    '''returns n!'''
    return 1 if n < 2 else n * factorial(n-1)

fact = factorial

# %%
factorial(42)
# Out:
# 1405006117752879898543142606244511569936384000000000

# %%
factorial.__doc__
# Out:
# 'returns n!'

# %%
type(factorial)
# Out:
# function

# %%
map(fact, range(11))

# %%
list(map(fact, range(11)))
# Out:
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]

# %%
# 5-3 고위함수 예제

# %%
fruits = ['strawberry', 'fig', 'apple', 'cherry', 'raspberry', 'banana']
sorted(fruits, key=len)
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspberry', 'strawberry']

# %%
# 5-4 역순으로 정렬

# %%
def reverse(work):
    return work[::-1]
reverse('testing')
# Out:
# 'gnitset'

# %%
sorted(fruits, key=reverse)
# Out:
# ['banana', 'apple', 'fig', 'raspberry', 'strawberry', 'cherry']

# %%
# map ( ), filter ( ), reduce ( )의 대안

# %%
# 5-5
list(map(fact, range(6)))
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
[fact(n) for n in range(6)]
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
list(map(factorial, filter(lambda n: n % 2, range(6))))
# Out:
# [1, 6, 120]

# %%
[factorial(n) for n in range(6) if n % 2]
# Out:
# [1, 6, 120]

# %%
# 5-6 sum 구하기

# %%
from functools import reduce
from operator import add

# %%
reduce(add, range(100))
# Out:
# 4950

# %%
sum(range(100))
# Out:
# 4950

# %%
# 익명함수

# %%
# 5-7

# %%
sorted(fruits, key=lambda word: word[::-1])
# Out:
# ['banana', 'apple', 'fig', 'raspberry', 'strawberry', 'cherry']

# %%
"""
람다 리팩토링
1. 람다를 설명하는 주석을 작성한다
2. 주석의 본질을 전달하는 이름을 생각한다
3. 그 이름으로 람다를 def 문으로 변경한다
4. 주석을 제거한다

람다도 def 와 마찬가지로 하나의 함수 객체를 만든다
"""
# Out:
# '\n람다 리팩토링\n1. 람다를 설명하는 주석을 작성한다\n2. 주석의 본질을 전달하는 이름을 생각한다\n3. 그 이름으로 람다를 def 문으로 변경한다\n4. 주석을 제거한다\n\n람다도 def 와 마찬가지로 하나의 함수 객체를 만든다\n'

# %%
# callable function

# %%
# 5-8

# %%
import random

class BingoCage:
    def __init__(self, items):
        self._items = list(items)
        random.shuffle(self._items)
        
    def pick(self):
        try:
            return self._items.pop()
        except IndexError:
            raise LookupError('empty BingoCage')
    
    def __call__(self):
        return self.pick()

# %%
bingo = BingoCage(range(3))

# %%
bingo.pick()
# Out:
# 0

# %%
bingo()
# Out:
# 1

# %%
# 일반 객체에는 없는 함수 속성들
class C: pass
obj = C()
def func(): pass
sorted(set(dir(func)) - set(dir(obj)))
# Out:
# ['__annotations__',
#  '__call__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__get__',
#  '__globals__',
#  '__kwdefaults__',
#  '__name__',
#  '__qualname__']

# %%
# 5-10 키워드 전용 파라미터

# %%
def tag(name, *content, cls=None, **attrs):
    if cls is not None:
        attrs['class'] = cls
    if attrs:
        attr_str = ''.join(' %s="%s"' % (attr, value) 
            for attr, value in sorted(attrs.items()))
    else:
        attr_str = ''
    
    if content:
        return '\n'.join('<%s%s>%s</%s>' % (name, attr_str, c, name) 
                         for c in content)
    else:
        return '<%s%s />' % (name, attr_str)

# %%
tag('br')
# Out:
# '<br />'

# %%
tag('p', 'hello')
# Out:
# '<p>hello</p>'

# %%
tag('p', 'hello', 'world')
# Out:
# '<p>hello</p>\n<p>world</p>'

# %%
tag('p', 'hello', id=30)
# Out:
# '<p id="30">hello</p>'

# %%
tag('p', 'hello', 'world', id=30, cls='sidebar')
# Out:
# '<p class="sidebar" id="30">hello</p>\n<p class="sidebar" id="30">world</p>'

# %%
my_tag = {'name': 'img', 'title': 'sunset boulevard', 
          'src': 'sunset.jpg', 'cls': 'framed'}

# %%
tag(**my_tag)
# Out:
# '<img class="framed" src="sunset.jpg" title="sunset boulevard" />'

# %%
# 5-15 원하는 길이 가까이에 있는 공백에서 잘라서 문자열을 단축하는 함수

# %%
def clip(text, max_len=80):
    """max_len 앞이나 뒤의 마지막 공백에서 잘라낸 텍스트를 반환한다. """
    end = None
    if len(text) > max_len:
        space_before = text.rfind(' ', 0, max_len) 
        if space_before >= 0:
            end = space_before 
        else:
            space_after = text.rfind(' ', max_len) 
            if space_after >= 0:
                end = space_after 
    if end is None: # 공백이 없다.
        end = len(text)
    return text[:end].rstrip()

# %%
# 5-16 함수 인자에 대한 정보 추출하기

# %%
clip.__defaults__
# Out:
# (80,)

# %%
clip.__code__
# Out:
# <code object clip at 0x10cf744b0, file "<ipython-input-2-e21a328d5a4c>", line 1>

# %%
clip.__code__.co_varnames
# Out:
# ('text', 'max_len', 'end', 'space_before', 'space_after')

# %%
clip.__code__.co_argcount
# Out:
# 2

# %%
# 5-17 함수 시그니처 추출하기

# %%
from inspect import signature

# %%
sig = signature(clip)

# %%
sig
# Out:
# <Signature (text, max_len=80)>

# %%
str(sig)
# Out:
# '(text, max_len=80)'

# %%
for name, param in sig.parameters.items():
    print(param.kind, ':', name, '=', param.default)
# Out:
# POSITIONAL_OR_KEYWORD : text = <class 'inspect._empty'>
# POSITIONAL_OR_KEYWORD : max_len = 80

# %%
# 5-18

# %%
import inspect

# %%
sig = inspect.signature(tag)

# %%
my_tag = {'name':'img', 'title':'sunset', 'src':'suncet.jpg', 'cls':'framed'}

# %%
bound_args = sig.bind(**my_tag)

# %%
bound_args
# Out:
# <BoundArguments (name='img', cls='framed', attrs={'title': 'sunset', 'src': 'suncet.jpg'})>

# %%
for name, value in bound_args.arguments.items():
    print(name, '=', value)
# Out:
# name = img
# cls = framed
# attrs = {'title': 'sunset', 'src': 'suncet.jpg'}

# %%
del my_tag['name']

# %%
bound_args = sig.bind(**my_tag)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-1e763c041430> in <module>()
# ----> 1 bound_args = sig.bind(**my_tag)
#
# /usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/inspect.py in bind(*args, **kwargs)
#    2919         if the passed arguments can not be bound.
#    2920         """
# -> 2921         return args[0]._bind(args[1:], kwargs)
#    2922
#    2923     def bind_partial(*args, **kwargs):
#
# /usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/inspect.py in _bind(self, args, kwargs, partial)
#    2834                             msg = 'missing a required argument: {arg!r}'
#    2835                             msg = msg.format(arg=param.name)
# -> 2836                             raise TypeError(msg) from None
#    2837             else:
#    2838                 # We have a positional argument to process
#
# TypeError: missing a required argument: 'name'

# %%
# 5-19 애노테이션을 추가

# %%
def clip(test:str, max_len:'int > 0'=80) -> str:
    """max_len 앞이나 뒤의 마지막 공백에서 잘라낸 텍스트를 반환
    """
    end = None
    if len(text) > max_len:
        space_before = tex.rfind(' ' , 0, max_len)
        if spce_before >= 0:
            end = space_before
        else:
            space_after = text.rfind(' ', max_len)
            if space_after >= 0:
                end = space_after
    if end is None:
        end = len(text)
    return text[:end].rstrip()

# %%
clip.__annotations__
# Out:
# {'max_len': 'int > 0', 'return': str, 'test': str}
